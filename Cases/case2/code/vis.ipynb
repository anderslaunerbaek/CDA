# %% [markdown]
# # Transferlearning

# %%
import numpy as np
import matplotlib.pyplot as plt
from my_class import my_class as my
from sklearn.decomposition import PCA
# %matplotlib inline

# %%
# load
X = np.load("./../data/tmp/X.npy")
Y = np.load("./../data/tmp/Y.npy")
# standardize
X_norm = (X - np.mean(X, axis=0)) / np.std(X, axis=0)

# %%
# 
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_norm)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=np.argmax(Y, 1), alpha=1.0)
plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.legend(loc=2)
plt.show()

# %%
pca.explained_variance_ratio_

0.65947501 + 0.20884169
# Out:
# 0.8683166999999999

# %%
X_pca[:, 0], X_pca[:, 1]

# %%
for ii in range(0,X_pca.shape[0]):
    if np.argmax(Y, 1)[ii]==1:
        print("(",X_pca[ii, 0],",",X_pca[ii, 1],")")
# Out:
# ( -3.49546660461 , -1.32489679255 )
# ( -2.8943875943 , -0.995106157272 )
# ( -2.8943875943 , -0.995106157272 )
# ( -3.49546660461 , -1.32489679255 )
# ( -3.49546660461 , -1.32489679255 )
# ( -2.8943875943 , -0.995106157272 )
# ( -2.8943875943 , -0.995106157272 )
# ( -2.8943875943 , -0.995106157272 )
# ( -2.8943875943 , -0.995106157272 )
# ( -3.49546660461 , -1.32489679255 )
# ( -3.49546660461 , -1.32489679255 )
# ( -3.49546660461 , -1.32489679255 )
# ( 0.443232539214 , 0.240770975854 )
# ( 0.443232539214 , 0.240770975854 )
# ( 0.443232539214 , 0.240770975854 )
# ( 0.443232539214 , 0.240770975854 )
# ( 0.443232539214 , 0.240770975854 )
# ( 0.443232539214 , 0.240770975854 )
# ( -0.410381282626 , -0.767911579432 )
# ( -0.410381282626 , -0.767911579432 )
# ( -0.410381282626 , -0.767911579432 )
# ( -0.410381282626 , -0.767911579432 )
# ( -0.410381282626 , -0.767911579432 )
# ( -0.410381282626 , -0.767911579432 )
# ( -1.68286359864 , -0.488931003199 )
# ...

# %%
# standardize
X = np.load("./../data/tmp/X_transfer.npy")
Y = np.load("./../data/tmp/Y_transfer.npy")
X_norm = (X - np.mean(X, axis=0)) / np.std(X, axis=0)

# %%
X_pca = pca.fit_transform(X_norm)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=np.argmax(Y, 1), alpha=0.5)
plt.xlabel("PCA1")
plt.ylabel("PCA2")
plt.legend(loc=2)
plt.show()
